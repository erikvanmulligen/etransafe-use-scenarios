# %% [markdown]
# # eTransafe Concordance analysis
#
# This is the use scenario that has been described by Thomas Steger-Hartmann in a publication with Matthew Clark.
# The idea is to compare animal observations with clinical observations for the various drugs
# 1. determine the drugs that have been used in the preclinical and the clinical domain
# 2. compare the individual PTs for preclinical and clinical
# 3. compute the concordance matrix
#     1. aggregate the PT terms per PT, HLT, or SOC level
#     2. for each drug, count how many terms are in the TP, FP, TN, FN bins
# 4. Visualize the matrix
#
# (C) 2022 Erasmus University Medical Center, Rotterdam, The Netherlands
# Author: Erik M. van Mulligen, e.vanmulligen@erasmusmc.nl

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from knowledgehub.api import KnowledgeHubAPI
from Concordance.condordance_utils import getClinicalDatabases, getPreclinicalDatabases
from Concordance.mapper import Mapper

import ipywidgets as w
from IPython.display import display, Javascript
from ipypublish import nb_setup
import numpy as np
import json
import mysql.connector

import warnings
warnings.filterwarnings('ignore')

# %%
api = KnowledgeHubAPI(server='DEV', client_secret='3db5a6d7-4694-48a4-8a2e-e9c30d78f9ab')
mapper = Mapper(api)

# %% [markdown]
# ## Authenticate for KnowledgeHub

# %%
username = w.Text(value='tester',placeholder='Knowledge Hub account', description='username:', disabled=False)
password = w.Password(value='', placeholder='Knowledge Hub password', description='password:', disabled=False)
loginBtn = w.Button(description='Login')
status = w.Output()

def on_button_clicked(_):
    if not api.login(username.value, password.value):
        print("Failed to login")
    else:
        print("successfully logged in")
        display(Javascript('IPython.notebook.execute_cell_range(IPython.notebook.get_selected_index()+1, IPython.notebook.get_selected_index()+2)'))


loginBtn.on_click(on_button_clicked)
w.VBox([username, password, loginBtn])
# Out:
# VBox(children=(Text(value='tester', description='username:', placeholder='Knowledge Hub account'), Password(de…
# successfully logged in

# %% [markdown]
# ## Authenticate for the data stored in the database

# %%
global db

dbhost = w.Text(value='localhost',placeholder='database host', description='host:', disabled=False)
dbdatabase = w.Text(value='concordance-20220524',placeholder='database name', description='database:', disabled=False)
dbusername = w.Text(value='root',placeholder='database username', description='username:', disabled=False)
dbpassword = w.Password(value='', placeholder='database password', description='password:', disabled=False)
dbLoginBtn = w.Button(description='Login')
status = w.Output()

def dbLoginBtn_click(_):
    global db
    try:
        db = mysql.connector.connect(host=dbhost.value, database=dbdatabase.value, user=dbusername.value, password=dbpassword.value)
        print("successfully logged in database")
        display(Javascript('IPython.notebook.execute_cell_range(IPython.notebook.get_selected_index()+1, IPython.notebook.get_selected_index()+2)'))
    except Exception as e:
        print("failed to log in database")
        sys.exit(0)
    
dbLoginBtn.on_click(dbLoginBtn_click)
w.VBox([dbhost, dbdatabase, dbusername, dbpassword, dbLoginBtn])
# Out:
# VBox(children=(Text(value='localhost', description='host:', placeholder='database host'), Text(value='concorda…
# successfully logged in database

# %% [markdown]
# ## The database
# In order to be able to compute the concordance tables we have constructed a database with all preclinical and clinical findings found for drugs (i.e. inchikeys) that are both found in the preclinical and clinical data. For the preclinical data we restricted to findings that are treatment related and not in the control group. For each of the preclinical findings we checked with the semantic service whether the equivalent clinical finding was found in the clinical findings and vice versa. This is stored in the database as 'mapped' per finding. For each of the preclinical and clinical findings we derived the MedDRA PT it is related to. For preclinical terms this is done through the semantic service. For clinical terms the findings are already expressed as MedDRA PT terms. These mappings are stored in the database as 'PT' per finding.

# %% [markdown]
# ## Drug mapping
# We maintain a list of drugs that can be found in the preclinical and clinical data with its inchi-group (inchi-group being the first 14 characters of an inchi-key). Per drug we have stored the finding ids that are associated per database.

# %%
cursor = db.cursor()
cursor.execute('SELECT inchi_group, inchi_keys, names FROM drugs')
drugs = [{'inchi_group': r[0], 'inchi_keys': [i for i in r[1].split(',')], 'names':[i for i in r[2].split(',')]} for r in cursor.fetchall()]
print(f'{len(drugs)} drugs found')
# Out:
# 201 drugs found

# %% [markdown]
# ## Overview of the drugs

# %%
pd = nb_setup.setup_pandas(escape_latex=False)
df = pd.DataFrame(np.random.rand(len(drugs),3),columns=['inchi_group','inchi_key','name'])
df.inchi_group = [drugs[d]['inchi_group'] for d in drugs]
df.inchi_key = [drugs[d]['inchi_keys'][0] for d in drugs]
df.name = [drugs[d]['name'][0] for d in drugs]
df.round(3)
# Out:
#     inchiKey        clinicalName             \
# 0    GDLIGKIOYRNHDA            clomipramine
# 1    OZVBMTJYIDMWIL           bromocriptine
# 2    KPYSYYIEGFHWSV                baclofen
# 3    QZUDBNBUXVUHMW               clozapine
# 4    ZNRGQMMCGHDTEI             tropisetron
# 5    XPCFTKFZXHTYIP              benazepril
# 6    WRUUGTRCQOWXEG             pamidronate
# 7    WDQPAMHFFCXSNU             clofazimine
# 8    YNZFUWZUGRBMHL               opipramol
# 9    LBXHRAWDUMTPSE               clopamide
# 10   JIVPVXMEBJLZRO          chlorthalidone
# 11   HCYAFALTSJYZDH             desipramine
# 12   GGXMRPUKBWXVHE            halometasone
# 13   FIADGNVRKBPQEU              pizotyline
# 14   BCGWQEUPMDMJNV              imipramine
# 15   MBGGBVCUIVRRBF          sulfinpyrazone
# 16   XCTYLCDETUVOIP        thiethylperazine
# 17   JZQKKSLKJUAGIC                pindolol
# 18   VYMDGNCVAMGZFE          phenylbutazone
# 19   DKNWSYNQZKUICI              amantadine
# 20   INJOMKTZOLKMBF              guanfacine
# 21   ACGDKVXYNVEAGU            guanethidine
# 22   DCMJBKFKXGPPMT             cizolirtine
# 23   VQKLRVZQQYVIJW           dihydralazine
# 24   KLBQZWRITKRQQV            thioridazine
# 25   QSLMDECMDJKHMQ             maprotiline
# 26   OSVMTWJCGUFAOD              formestane
# 27   NQPDXQQQCQDHHW         triclabendazole
# 28   OVCDSSHSILBFBN             amodiaquine
# 29   AGOYDEPGAOXOCK          clarithromycin
# 30   UWKQSNNFCGGAFS              irinotecan
# 31   YGCFIWIQZPHFLU              acesulfame
# 32   XUKUURHRXDUEBC            atorvastatin
# 33   RBQOQRRFDPXAGN         propentofylline
# 34   DKOQGJHPHLTOJR               cefpirome
# 35   WNMJYKCGWZFFKR               alfuzosin
# 36   WIGIZIANZCJQQY             glimepiride
# 37   UNRHXEPDKXPRTM              sultopride
# 38   QURWXBZNHXJZBE               icatibant
# 39   ORYDPOVDJJZGHQ            Tirapazamine
# 40   LJVAJPDWBABPEJ           telithromycin
# 41   NGGMYCMLYOUNGM              fumagillin
# 42   IMZMKUWMOSJXDT                cromolyn
# 43   IYIKLHRQXLHMJQ              amiodarone
# 44   AAOVKJBEBIDNHE                diazepam
# 45   AHLBNYSZXLDEJQ                orlistat
# 46   SHGAZHPCJJPHSC            isotretinoin
# 47   ZNNLBTZKUZBEKO               glyburide
# 48   SCKYRAXSEDYPSA              ciclopirox
# 49   ZZUFCTLCJUWOSV              furosemide
# 50   GSDSWSVVBLHKDQ               ofloxacin
# 51   PZRHRDRVRGEVNW               milrinone
# 52   RQTOOFIXOKYGAN              nedocromil
# 53   HDACQVRGBOVJII                ramipril
# 54   FTALBRSUTCGOEG                riluzole
# 55   GMZVRMREEHBGGF               piracetam
# 56   QSXXLDDWVCEBFP            torbafylline
# 57   CUWODFFVMXJOKD               buserelin
# 58   VHOGYURTWQBHIL             leflunomide
# 59   BYPFEZZEUUWMEJ          pentoxifylline
# 60   FZNCGRZWXLXZSZ               voglibose
# 61   XLFWDASMENKTKL             molsidomine
# 62   GPRBEKHLDVQUJE              cefotaxime
# 63   VXFJYXUZANRPDJ            trandolapril
# 64   OHCQJHSOBUTRHG               Colforsin
# 65   QVSXOXCYXPQXMF               alniditan
# 66   OZFSWVOEXHGDES              lubeluzole
# 67   GXPHKUHSUJUWKP            troglitazone
# 68   PVLJETXTTWAYEW             mizolastine
# 69   YOSHYTLCDANDAN              irbesartan
# 70   RPTUSVTUFVMDQK             hydralazine
# 71   UBQYURCVBFRUQT            deferoxamine
# 72   QPGGEKPRGVJKQB              dibenzepin
# 73   ROBVIMPUHSLWNV       aminoglutethimide
# 74   PXWLVJLKJGVOKE          propyphenazone
# 75   MRBDMNSDAVCSSF            phentolamine
# 76   ZQDWXGKKHFNSQK             hydroxyzine
# 77   PTOJVMZPWPAXER               Enprostil
# 78   PUXBGTOOZJQSKH               carprofen
# 79   JDUBGYFRJFOXQC            capivasertib
# 80   WAXQNWCZJDTGBU              netupitant
# 81   HHHKFGXWKKUNCY              cilazapril
# 82   OZGNYLLQHRPOBR               naftifine
# 83   ZIXNZOBDFKSQTC              cloxazolam
# 84   DKWNMCUOEDMMIN              melagatran
# 85   OUKYUETWWIPKQR             saracatinib
# 86   PDOQBOJDRPLBQU                AZD 1480
# 87   JUSFANSTBFGBAF             vistusertib
# 88   XXJWYDDUDKYVKI               cediranib
# 89   FDLYAMZZIXQODN                olaparib
# 90   LJNUIEQATDYXJH             lesogaberan
# 91   JMEYDSHPKCSIJC                 AZD3514
# 92   OEKWJQXRCDYSHL              ticagrelor
# 93   XFLQIRAKKLNXRQ              elobixibat
# 94   XULSCZPZVQIMFM              odevixibat
# 95   FNYFFCOCVNTJCD                 AZD9164
# 96   XGALLCVXEZPNRQ               gefitinib
# 97   FJHHZXWJVIEFGJ                  ZD4054
# 98   SEERZIQQUAZTOL            cerivastatin
# 99   HBUJYEUPIIJJOS               posizolid
# 100  AAKJLRGGTJKAMG               erlotinib
# 101  INVTYAOGFAGBOE              entinostat
# 102  CXGTZJYQWSUFET            tesaglitazar
# 103  RYMZZMVNJRMUDD             simvastatin
# 104  JZCPYUJPEARBJL              Rimonabant
# 105  CGIGDMFJXJATDK            indomethacin
# 106  GJSURZIOUXUGAL               clonidine
# 107  ANTSCNMPPGJYLG        chlordiazepoxide
# 108  ZCCUWMICIWSJIX     ceftaroline fosamil
# 109  CMSMOCZEIVJLDB        cyclophosphamide
# 110  IMYZQPCYWPFTAG            mecamylamine
# 111  SNICXCGAKADSCV                nicotine
# 112  LKJPYSCBVHEWIU            bicalutamide
# 113  YBBLVLTVTVSKRW             anastrozole
# 114  ZFMITUMMTDLWHR               minoxidil
# 115  HLFSDGLLUJUHTE              levamisole
# 116  LMEKQMALGUDUQG            azathioprine
# 117  YASAKCUCGLMORW           rosiglitazone
# 118  ZKMNUMMKYBVTFN             ropivacaine
# 119  VREFGVBLTWBCJP              alprazolam
# 120  ULSDMUVEXKOYBU            zolmitriptan
# 121  KWTSXDURSIMDCE             amphetamine
# 122  RZTAMFZIAATZDJ              felodipine
# 123  OIRDTQYFTABQOQ               adenosine
# 124  BPZSYCZIITTYBL              formoterol
# 125  VOVIALXJUBGFJZ              budesonide
# 126  YEEZWCHGZNKEEK             zafirlukast
# 127  IVTVGDXNLFLDRM             raltitrexed
# 128  ZJAOAACCNHFJAH               foscarnet
# 129  GUJRSXAPGDDABA             remoxipride
# 130  JLKIGFTWXXRPMT        sulfamethoxazole
# 131  ANZXOIAKUNOVQU              bambuterol
# 132  CEUORZQYGODEFX            aripiprazole
# 133  KVWDHTXUZHCGIO              olanzapine
# 134  SUBDBMMJDZJVOS              omeprazole
# 135  NNJVILVZKWQKPM               lidocaine
# 136  SZRPDCCEHVWOJX          pirinixic acid
# 137  ZXIBCJHYVWYIKI            ximelagatran
# 138  XSNMGLZVFNDDPW                AZD 0837
# 139  GUBGYTABKSRVRQ                 lactose
# 140  DCOPUUMXTXDBNB              diclofenac
# 141  SIQPXVQCUCHWDI            enprofylline
# 142  VOXZDWNPVJITMN               estradiol
# 143  VWUXBMIQPBEWFH             fulvestrant
# 144  VMXUWOKSQNHOCA              ranitidine
# 145  ZMHOBBKJBYLXFR              almokalant
# 146  RDOIQAHITMMDAJ              loperamide
# 147  UGFHIPBXIWJXNA               liarozole
# 148  XZWYZXLIPXDOLR               metformin
# 149  JQXXHWHPUNPDRT                rifampin
# 150  ZPXSCAKFGYXMGA                mazindol
# 151  NJMYODHXAKYRHW            flupenthixol
# 152  YSGASDXSLKIKOD              remacemide
# 153  GTPHQORJKFJIRB             frakefamide
# 154  UHTHHESEBZOYNR              vandetanib
# 155  BPRHUIZQVSMCRT            rosuvastatin
# 156  OLBCVFGFOZPWHH                propofol
# 157  TUZYXOIXSAXUGO             pravastatin
# 158  XWTYSIMOBUGWOL             terbutaline
# 159  HPJKCIUCZWXJDR               letrozole
# 160  MWTBKTRZPHJQLH             alcaftadine
# 161  GLLPUTYLZIKEGF                ridogrel
# 162  VHVPQPYKVGDNFY            itraconazole
# 163  XMGQYMWWDOXHJM                limonene
# 164  UURAUHCOJAIIRQ       tiamulin fumarate
# 165  DCSUBABJRXZOMT               cisapride
# 166  XLMPPFTZALNBFS                vorozole
# 167  YXFNPRHZMOGREC                 AZD7687
# 168  RPCVIAXDAUMJJP            ispronicline
# 169  BYBLEWFAAKGYCD              miconazole
# 170  GGCSSNBKKAUURC              sufentanil
# 171  IDBPHNDTYPBSNI              alfentanil
# 172  RKLNONIVDFXQRX             bromperidol
# 173  MDLAAYDRRZXJIF             penfluridol
# 174  QPUVKSKJCNGSGT                AZD-3043
# 175  ACRHBAYQBXXRTO              ivabradine
# 176  IRLWJILLXJGJTD            muraglitazar
# 177  PMRYVIKBURPHAH             methimazole
# 178  MVWVFYHBGMAFLY             ziprasidone
# 179  PJMPHNIQZUBGLI                fentanyl
# 180  IHEHEFLXQFOQJO           pirinitramide
# 181  ZCGOMHNNNFPNMX           levocabastine
# 182  FPCCSQOGAWCVBH              ketanserin
# 183  SMANXXCATUTDDT             flunarizine
# 184  MUMGGOZAMZWBJJ            testosterone
# 185  XJGVXQDUIWGIRW                loxapine
# 186  QWGDMFLQWFTERH               amoxapine
# 187  OVTCHWSLKGENKP       disufenton sodium
# 188  LBOJYSIDWZQNJS     Dizocilpine Maleate
# 189  NAUWTFJOPJWYOT              vanoxerine
# 190  UREBDLICKHMUKA           betamethasone
# 191  XNKCCCKFOQNXKV               naloxegol
# 192  YMBXTVYHTMGZDW              loxoprofen
# 193  ZSKVGTPCRGIANV                imipenem
# 194  RZVAJINKPMORJF           acetaminophen
# 195  DUYJMQONPNNFPI             osimertinib
# 196  MVFGUOIZUNYYSO              prilocaine
# 197  KPBZROQVTHLCDU             clevidipine
# 198  PAEBIVWUMLRPSK               cangrelor
# 199  VAOCPAMSLUNLGC           metronidazole
# 200  WDOGQTQEKVLZIJ           fosbretabulin
# 201  ZWJINEZUASEZBH            fenamic acid
# 202  APKFDSVGJQXUKY          amphotericin B
# 203  YPHMISFOHDHNIV           Cycloheximide
# 204  URKOMYMAXPYINW              quetiapine
# 205  DZGWFCGJZKJUFP                tyramine
# 206  WSEQXVZVJXJVFP              citalopram
# 207  IIRWNGPLJQXWFJ                 AT13148
# 208  CYOHGALHFOKKQC             selumetinib
# 209  TVURRHSHRRELCG              fenoldopam
# 210  JOLJIIDDOBNFHW              xanomeline
# 211  MPIPASJGOJYODL             isoconazole
# 212  KOHIRBRYDXPAMZ               nebivolol
# 213  XAIPTRIXGHTTNT             triflumuron
# 214  IAJOBQBIJHVGMQ        phosphinothricin
# 215  PXMNMQRDXWABCY            tebuconazole
# 216  HOKKPVIRMVDYPB             thiacloprid
# 217  MLDQJTXFUGDVEO               sorafenib
# 218  FABPRXSRWADJSP            moxifloxacin
# 219  TYZROVQLWOKYKF               linezolid
# 220  SECKRCOLJRRGGV              vardenafil
# 221  BNRNXUUZRGQAQC              sildenafil
# 222  DGAIEPBNLOQYER               iopromide
# 223  DKYWVDODHFEZIM              ketoprofen
# 224  BSYNRYMUTXBXSQ                 aspirin
# 225  UIAGMCDKSXEBJQ              nimodipine
# 226  OCAPBUJLXMYKEJ              bifonazole
# 227  VKQFCGNPDRICFG             nisoldipine
# 228  XILVEPYQJIOVNB             etofenamate
# 229  ODUOJXZPIYUATO            racecadotril
# 230  TZJUVVIWVWFLCD              ipsapirone
# 231  OIGNJSKKLXVSLS            prednisolone
# 232  METQSPRSQINEEU            drospirenone
# 233  XUHXFSYUBXNTHU                iotrolan
# 234  NDAUXUAQIAJITI               albuterol
# 235  HIFJCPQKFCZDDL                iloprost
# 236  IEXUMDBQLIVNHZ             onapristone
# 237  RLFKILXOLJVUNF               abecarnil
# 238  JJJFUHOGVZWXNQ             Enbucrilate
# 239  AOJJSUZBOXZQNB             doxorubicin
# 240  BFZKMNSQCNVFGM              sagopilone
# 241  ZDZOTLJHXYCWBA               docetaxel
# 242  YAKWPXVTIGTRJH             fotemustine
# 243  DJSXNILVACEBLP      strontium ranelate
# 244  DRLFMBDRBRZALE               melatonin
# 245  IPVQLZZIHOAWMC             perindopril
# 246  DDUHZTYCFQRHIY            griseofulvin
# 247  WPVFJKSGQUFQAP          valganciclovir
# 248  RTGDFNSFWBGLEC   mycophenolate mofetil
# 249  OGHNVEJMJSYVRP              carvedilol
# 250  QWAXKHKRTORLEM              saquinavir
# 251  XMXHEBAFVSFQEX             iloperidone
# 252  FJLGEFLZQAZZCD             fluvastatin
# 253  ACWBQPMHZXGDFX               valsartan
# 254  CEMAWMOMDPGJMB              oxprenolol
# 255  CTRLABGOLIVAIY           oxcarbazepine
# 256  NLVFBUXFDBBNBW              tobramycin
# 257  HHZIURLSWUIHRB               nilotinib
# 258  JRURYQJSLYLRLN              entacapone
# 259  KHPKQFYUPIUARC             lumiracoxib
# 260  XSVMFMHYUFZWBK            rivastigmine
# 261  HPNSFSBZBAHARI       mycophenolic acid
# 262  JZUFKLXOESDKRF     hydrochlorothiazide
# 263  GGXKWVWZWMLJEH             famciclovir
# 264  KKGQTZUTZRNORY              fingolimod
# 265  BOFQWVMAQOTZIW             deferasirox
# 266  SYOKIDBDQMKNDQ            vildagliptin
# 267  FPOHNWQLNRZRFC            panobinostat
# 268  IQFYYKKMVGJFEH             telbivudine
# 269  HMJIYCCIJYRONP              isradipine
# 270  KTUFNOKKBVMGRW                imatinib
# 271  UXOWGYHJODZGMF               aliskiren
# 272  DOMXUEMWDBAQBQ             terbinafine
# 273  HRWCVUIFMSZDJS               spirapril
# 274  HKVAMNSJSFKALM              everolimus
# 275  PMATZTZNYRCHOR            cyclosporine
# 276  GDFGTRDCCWFXTG             quinagolide
# 277  IUBSYMUCCVWXPE              metoprolol
# 278  XRASPMIURGNCCH         zoledronic acid
# 279  XFYDIVBRZNQMJC              tizanidine
# 280  UPMXNNIRAGDFEH              bromoxynil
# 281  OWZREIFADZCYQD             decamethrin
# 282  QQODLKZGRKWIFG              cyfluthrin
# 283  RWTNPBWLLIMQHL            fexofenadine
# 284  KPQZUUQMTUIKBP             secnidazole
# 285  PHWBOXQYWZNQIN             ticlopidine
# 286  DDLIGBOFAVUZHB               midazolam
# 287  VAAUVRVFOQPIGI             ceftriaxone
# 288  ZROUQTNYPCANTN  Tiapamil Hydrochloride
# 289  OZWKMVRBQXNZKK               ketorolac
# 290  SAADBVWGJQAEFS              flurazepam
# 291  QEVHRUUCFGRFIF               reserpine
# 292  KASDHRXLYQOAKZ            pimecrolimus
# 293  LUZRJRNZXALNLM       dihydroergotamine
# 294  IKBKZGMPCYNSLU               tegaserod
# 295  UUOJIACWOAYWEZ              bopindolol
# 296  DEQANNDTNATYII              octreotide
# 297  BMPDWHIDQYTSHX         eslicarbazepine
# 298  KPJZHOPZRAFDTN            methysergide
# 299  VMZMNAABQBOLAK             pasireotide
# 300  HTIQEAQVCYTUBX              amlodipine
# 301  FAKRSMQSSFJEIM               captopril
# 302  YMTINGFKWWXKFG             fenofibrate
# 303  DDBREPKUVSBGFI           phenobarbital
#
#     preclinicalName
# 0                             Clomipramine HCl
# 1                                Bromocriptine
# 2                                     Baclofen
# 3                                     Clozapin
# 4                                  Tropisetron
# 5                                   Benazepril
# 6                         Pamidronate disodium
# 7                                  Clofazimine
# 8                                    Opipramol
# 9                                    Clopamide
# 10                              Chlorthalidone
# 11                   Desipramine Hydrochloride
# 12                                Halometasone
# 13                                   Pizotifen
# 14                    Imipramine hydrochloride
# 15                              Sulfinpyrazone
# 16                            Thiethylperazine
# 17                                    Pindolol
# 18                              Phenylbutazone
# 19                                  Amantadine
# 20                                  Guanfacine
# 21                                Guanethidine
# 22                                      E-4018
# 23                                Dihydralazin
# 24                                Thioridazine
# 25                                 Maprotiline
# 26                                  Formestane
# 27                             Triclabendazole
# 28                                 Amodiaquine
# 29                              Clarithromycin
# 30                                GGA-SAD-0043
# 31                                GGA-SAD-0044
# 32                                GGA-SAD-0048
# 33                                GGA-SAD-0051
# 34                           Cefpirome sulfate
# 35                                   Alfuzosin
# 36                                  Glimepirid
# 37                                 Amisulpride
# 38                                   Icatibant
# 39                                GGA-SAD-0057
# 40                               Telithromycin
# 41                                  Fumagillin
# 42                                GGA-SAD-0268
# 43                                  Amiodarone
# 44                                    Diazepam
# 45                                    Orlistat
# 46                                   Tretinoin
# 47                               Glibenclamide
# 48                                  Ciclopirox
# 49                                  Furosemide
# 50                                Levofloxacin
# 51                                   Milrinone
# 52                                GGA-SAD-0069
# 53                                    Ramipril
# 54                                    Riluzole
# 55                                   Piracetam
# 56                                GGA-SAD-0243
# 57                                GGA-SAD-0270
# 58                                 Leflunomide
# 59                              Pentoxifylline
# 60                                   Voglibose
# 61                                  Molsidomin
# 62                      Cefotaxime sodium salt
# 63                                Trandolapril
# 64                                   Forskolin
# 65                                 PLS_JJ_0004
# 66                                  Lubeluzole
# 67                                Troglitazone
# 68                                 Mizolastine
# 69                                  Irbesartan
# 70                                 Hydralazine
# 71                                Deferoxamine
# 72                                  Dibenzepin
# 73                           Aminoglutethimide
# 74                              Propyphenazone
# 75                                Phentolamine
# 76                                 GGA_UCB_w16
# 77                          Roche_PC_RO1084135
# 78                                   Carprofen
# 79                            AZ_GGA_203705648
# 80                                  Netupitant
# 81                                  Cilazapril
# 82                     Naftifine Hydrochloride
# 83                                  Cloxazolam
# 84                            AZ_GGA_200002123
# 85                            AZ_GGA_200010909
# 86                            AZ_GGA_203287608
# 87                            AZ_GGA_203287559
# 88                            AZ_GGA_200010232
# 89                                    Olaparib
# 90                            AZ_GGA_203287640
# 91                            AZ_GGA_204560569
# 92                                  Ticagrelor
# 93                            AZ_GGA_203287633
# 94                            AZ_GGA_203287597
# 95                            AZ_GGA_203287758
# 96                                   Gefitinib
# 97                            AZ_GGA_200003818
# 98                                Cerivastatin
# 99                            AZ_GGA_203287635
# 100                                  Erlotinib
# 101                           AZ_GGA_200007856
# 102                           AZ_GGA_200004465
# 103                           AZ_GGA_200006510
# 104                                 Rimonabant
# 105                           AZ_GGA_200002962
# 106                           AZ_GGA_200001874
# 107                           AZ_GGA_200003642
# 108                           AZ_GGA_200012432
# 109                           AZ_GGA_200000828
# 110                           AZ_GGA_203464217
# 111                                   Nicotine
# 112                               Bicalutamide
# 113                                Anastrozole
# 114                           AZ_GGA_200000048
# 115                           AZ_GGA_200000537
# 116                           AZ_GGA_200000517
# 117                              Rosiglitazone
# 118                                Ropivacaine
# 119                           AZ_GGA_200000614
# 120                               Zolmitriptan
# 121                                Amphetamine
# 122                                 Felodipine
# 123                                  Adenosine
# 124                           AZ_GGA_200003180
# 125                           AZ_GGA_200001430
# 126                                Zafirlukast
# 127                                Raltitrexed
# 128                                  Foscarnet
# 129                                Remoxipride
# 130                           Sulfamethoxazole
# 131                                 Bambuterol
# 132                               Aripiprazole
# 133                                 Olanzapine
# 134                               Esomeprazole
# 135  Lidocaine HCl monohydrate; Prilocaine HCl
# 136                           AZ_GGA_200010384
# 137                               Ximelagatran
# 138                           AZ_GGA_200008168
# 139                           AZ_GGA_201299465
# 140                           AZ_GGA_200003370
# 141                               Enprofylline
# 142                           AZ_GGA_200000247
# 143                           AZ_GGA_200001688
# 144                           AZ_GGA_203287149
# 145                           AZ_GGA_200006272
# 146                                 Loperamide
# 147                                PLS_JJ_0003
# 148         Metformin Hydrochloride.Glucophage
# 149                                Rifampicine
# 150                                   Mazindol
# 151                                Flupentixol
# 152                           AZ_GGA_200010557
# 153                           AZ_GGA_200009446
# 154                                 Vandetanib
# 155                           AZ_GGA_229587807
# 156                                   Propofol
# 157                           AZ_GGA_229575594
# 158                           AZ_GGA_200002534
# 159                                  Letrozole
# 160                                Alcaftadine
# 161                                   Ridogrel
# 162                               Itraconozole
# 163                                 d-limonene
# 164                                   Tiamulin
# 165                                  Cisapride
# 166                                PLS_JJ_0052
# 167                           AZ_GGA_203287598
# 168                           AZ_GGA_200004584
# 169                                 Miconazole
# 170                                    Citrate
# 171                                 Alfentanil
# 172                                Bromperidol
# 173                                Penfluridol
# 174                           AZ_GGA_200003726
# 175                   Ivabradine hydrochloride
# 176                            GGA_IRIS_SER007
# 177                                Methimazole
# 178                           AZ_GGA_200000818
# 179                           AZ_GGA_200002196
# 180                                Piritramide
# 181                Levocabastine hydrochloride
# 182                        Ketanserin tartrate
# 183                                Flunarizine
# 184                           AZ_GGA_200002665
# 185                                   Loxapine
# 186                                  Amoxapine
# 187                           AZ_GGA_200007423
# 188                           AZ_GGA_200003722
# 189                           AZ_GGA_200005931
# 190                           AZ_GGA_203287217
# 191                                  Naloxegol
# 192                                 Loxoprofen
# 193                           AZ_GGA_201384247
# 194                           AZ_GGA_200000519
# 195                                Osimertinib
# 196                                 Prilocaine
# 197                           AZ_GGA_200004244
# 198                                  Cangrelor
# 199                           AZ_GGA_200003324
# 200                           AZ_GGA_203340244
# 201                           AZ_GGA_200948603
# 202                           AZ_GGA_203352003
# 203                           AZ_GGA_202445285
# 204                                 Quetiapine
# 205                                   Tyramine
# 206                           AZ_GGA_200001716
# 207                           AZ_GGA_203314983
# 208                           AZ_GGA_200006224
# 209                           AZ_GGA_200002307
# 210                           AZ_GGA_200010081
# 211                        Isoconazole Nitrate
# 212                                  Nebivolol
# 213                         GGA_BCS_64628-44-0
# 214                         GGA_BCS_77182-82-2
# 215                        GGA_BCS_107534-96-3
# 216                        GGA_BCS_111988-49-9
# 217                                  Sorafenib
# 218                 Moxifloxacin hydrochloride
# 219                                  Linezolid
# 220                                    Levitra
# 221                                     Viagra
# 222                                  Ultravist
# 223                                 Ketoprofen
# 224                                    Aspirin
# 225                                 NIMODIPINE
# 226                                 Bifonazole
# 227                                Nisoldipine
# 228                                 Etofenamat
# 229                               Racecadotril
# 230                                 Ipsapirone
# 231                               Prednisolone
# 232                               Drospirenone
# 233                                   Iotrolan
# 234                                 Salbutamol
# 235                          Iloprost ventavis
# 236                                Onapristone
# 237                                  Abecarnil
# 238                                Enbucrilate
# 239                                 Adriamycin
# 240                                 Sagopilone
# 241                                   Taxotere
# 242                                   Muphoran
# 243                            GGA_IRIS_SER026
# 244                                  Melatonin
# 245                                Perindopril
# 246                               Griseofulvin
# 247                                    Valcyte
# 248                                   CellCept
# 249                                 Carvedilol
# 250                                 Saquinavir
# 251                                Iloperidone
# 252                                Fluvastatin
# 253                                  Valsartan
# 254                   Oxprenolol Hydrochloride
# 255                              Oxcarbazepine
# 256                                 Tobramycin
# 257                                  Nilotinib
# 258                                 Entacapone
# 259                                Lumiracoxib
# 260                               Rivastigmine
# 261                       Mycophenolate Sodium
# 262                        Hydrochlorothiazide
# 263                                Famciclovir
# 264                                 Fingolimod
# 265                                Deferasirox
# 266                               Vildagliptin
# 267                               Panobinostat
# 268                                Telbivudine
# 269                                 Isradipine
# 270                          Imatinib Mesylate
# 271                                  Aliskiren
# 272                                Terbinafine
# 273                    Spirapril Hydrochloride
# 274                                 Everolimus
# 275                                Ciclosporin
# 276                                Quinagolide
# 277                        Metoprolol Tartrate
# 278                            Zoledronic acid
# 279                   Tizanidine Hydrochloride
# 280                                 Bromoxynil
# 281                               Deltamethrin
# 282                               B-Cyfluthrin
# 283                           Fexofenadine HCl
# 284                                Secnidazole
# 285                                Ticlopidine
# 286                                  Midazolam
# 287                                 Ceftriaxon
# 288                                   Tiapamil
# 289                     Ketorolac Tromethamine
# 290                             Flurazepam HCI
# 291                                  Reserpine
# 292                               Pimecrolimus
# 293                          Dihydroergotamine
# 294                                  Tegaserod
# 295                                 Bopindolol
# 296                                 Octreodide
# 297                              Licarbazepine
# 298                               Methysergide
# 299                                Pasireotide
# 300                                 Amlodipine
# 301                                  Captopril
# 302                                Fenofibrate
# 303                              Phenobarbital

# %% [markdown]
# ## Concordance table
# Per drug retrieve the preclinical and clinical PT terms.
# - true positives are the PT terms that can be found present in the preclinical and clinical data per drug.
# - false positives are the PT terms that can be found in the preclinical data but not in the clinical data per drug
# - false negatives are the PT terms that can not be found in the preclinical data but in the clinical data per drug
# - true negatives are all PT terms that can not be found in the preclinical data and in the clinical data per drug

# %%
from Concordance.condordance_utils import getAllPreClinicalClinicalPTs, getPTDrugFindings, getAllPreclinicalClinicalDistances
from Concordance.meddra import MedDRA

level = 'soc'
pt_to_group = {}

def getGroup(meddra, pt, level):
    if not pt in pt_to_group:
        if level == 'pt':
            group = meddra.getPt(pt)
        elif level == 'hlt':
            group = meddra.getHLT(pt)
        elif level == 'soc':
            group = meddra.getSoc(pt)
        pt_to_group[pt] = list(group.keys())[0] if len(group) > 0 else None
    return pt_to_group[pt]

meddra = MedDRA(username=dbusername.value, password=dbpassword.value)
ClinicalDatabases = getClinicalDatabases(api);
PreclinicalDatabases = getPreclinicalDatabases(api);

groups = {}
preclinical_pts = {}
clinical_pts = {}
for drug in drugs:
    preclinical_pts[drug] = getPTDrugFindings(db=db, drugInfo=drugs[drug], databases=PreclinicalDatabases.keys(), table='preclinical_meddra')
    clinical_pts[drug] = getPTDrugFindings(db=db, drugInfo=drugs[drug], databases=ClinicalDatabases.keys(), table='clinical_meddra')

all_preclinical_clinical_pts = getAllPreClinicalClinicalPTs(db=db, tables=['preclinical_meddra','clinical_meddra'])
all_preclinical_clinical_distances = getAllPreclinicalClinicalDistances(db=db, tables=['preclinical_meddra','clinical_meddra'])

for pt in all_preclinical_clinical_pts:
    group = getGroup(meddra, pt, level)
    
    if group is not None:
        if not group in groups:
            groups[group] = {'tp': 0, 'fp': 0, 'fn': 0, 'tn': 0, 'drugs': [], 'distance': all_preclinical_clinical_distances[pt]}
        elif abs(groups[group]['distance']) > abs(all_preclinical_clinical_distances[pt]):
            groups[group]['distance'] = all_preclinical_clinical_distances[pt]

        for drug in drugs:
            if not drug in groups[group]['drugs']:
                groups[group]['drugs'].append(drug)
                if pt in preclinical_pts[drug]:
                    if pt in clinical_pts[drug]:
                        groups[group]['tp'] += 1
                    else:
                        groups[group]['fp'] += 1
                else:
                    if pt in clinical_pts[drug]:
                        groups[group]['fn'] += 1
                    else:
                        groups[group]['tn'] += 1

# %% [markdown]
# ## Concordance tables

# %%
from Concordance.condordance_utils import getName
from nbconvert import HTMLExporter
import codecs
import nbformat

def compute_lrp(group):
    sensitivity = compute_sensitivity(group)
    specificity = compute_specificity(group)
    if specificity is not None and sensitivity is not None:
        return sensitivity / (1 - specificity) if specificity != 1 else None
    else:
        return None

def compute_lrn(group):
    sensitivity = compute_sensitivity(group)
    specificity = compute_specificity(group)
    if specificity is not None and sensitivity is not None:
        return (1 - sensitivity) / specificity if specificity != 0 else None
    else:
        return None
    
def compute_chisquare(group):
    tp = group['tp']
    fp = group['fp']
    fn = group['fn']
    tn = group['tn']
    total = tp + fp + fn + tn
    e11 = ((tp + fp) * (tp + fn)) / total
    e12 = ((tp + fp) * (fp + tn)) / total
    e21 = ((fn + tn) * (tp + fn)) / total
    e22 = ((fn + tn) * (fp + tn)) / total
    try:
        return (((tp - e11)**2)/e11) + (((fp - e12)**2)/e12) + (((fn - e21)**2)/e21) + (((tn - e22)**2)/e22)
    except Exception as e:
        return None

def compute_sensitivity(group):
    tp = group['tp']
    fn = group['fn']
    return tp / (tp + fn) if (tp + fn) > 0 else None

def compute_specificity(group):
    fp = group['fp']
    tn = group['tn']
    return tn / (fp + tn) if (fp + tn) > 0 else None

group_title = 'MedDRA ' + level.upper()
pd.set_option('display.max_rows', None)
pd.set_option('display.colheader_justify', 'left')
pd.options.display.float_format = '{:.2f}'.format
df = pd.DataFrame(np.random.rand(len(groups),11),columns=[group_title,'min.distance', 'TP','FP', 'FN', 'TN', 'Sensitivity', 'Specificity', 'LR+', 'LR-', 'chi-square'])
df[group_title] = [getName(meddra, code, level) for code in groups]
df['min.distance'] = [groups[code]['distance'] for code in groups]
df.TP = [groups[code]['tp'] for code in groups]
df.FP = [groups[code]['fp'] for code in groups]
df.FN = [groups[code]['fn'] for code in groups]
df.TN = [groups[code]['tn'] for code in groups]
df['Sensitivity'] = [compute_sensitivity(groups[code]) for code in groups]
df['Specificity'] = [compute_specificity(groups[code]) for code in groups]
df['LR+'] = [compute_lrp(groups[code]) for code in groups]
df['LR-'] = [compute_lrn(groups[code]) for code in groups]
df['chi-square'] = [compute_chisquare(groups[code]) for code in groups]
df.round(3)
df = df.sort_values(by=['LR+'], ascending=False)
dfStyler = df.style.set_properties(**{'text-align': 'right'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
dfStyler.set_properties(subset=[group_title], **{'text-align': 'left'}).hide_index()
# Out:
# <style type="text/css">
# #T_9b2e3 th {
#   text-align: left;
# }
# #T_9b2e3_row0_col0, #T_9b2e3_row1_col0, #T_9b2e3_row2_col0, #T_9b2e3_row3_col0, #T_9b2e3_row4_col0, #T_9b2e3_row5_col0, #T_9b2e3_row6_col0, #T_9b2e3_row7_col0, #T_9b2e3_row8_col0, #T_9b2e3_row9_col0, #T_9b2e3_row10_col0, #T_9b2e3_row11_col0, #T_9b2e3_row12_col0, #T_9b2e3_row13_col0, #T_9b2e3_row14_col0, #T_9b2e3_row15_col0, #T_9b2e3_row16_col0, #T_9b2e3_row17_col0, #T_9b2e3_row18_col0, #T_9b2e3_row19_col0, #T_9b2e3_row20_col0 {
#   text-align: right;
#   text-align: left;
# }
# #T_9b2e3_row0_col1, #T_9b2e3_row0_col2, #T_9b2e3_row0_col3, #T_9b2e3_row0_col4, #T_9b2e3_row0_col5, #T_9b2e3_row0_col6, #T_9b2e3_row0_col7, #T_9b2e3_row0_col8, #T_9b2e3_row0_col9, #T_9b2e3_row0_col10, #T_9b2e3_row1_col1, #T_9b2e3_row1_col2, #T_9b2e3_row1_col3, #T_9b2e3_row1_col4, #T_9b2e3_row1_col5, #T_9b2e3_row1_col6, #T_9b2e3_row1_col7, #T_9b2e3_row1_col8, #T_9b2e3_row1_col9, #T_9b2e3_row1_col10, #T_9b2e3_row2_col1, #T_9b2e3_row2_col2, #T_9b2e3_row2_col3, #T_9b2e3_row2_col4, #T_9b2e3_row2_col5, #T_9b2e3_row2_col6, #T_9b2e3_row2_col7, #T_9b2e3_row2_col8, #T_9b2e3_row2_col9, #T_9b2e3_row2_col10, #T_9b2e3_row3_col1, #T_9b2e3_row3_col2, #T_9b2e3_row3_col3, #T_9b2e3_row3_col4, #T_9b2e3_row3_col5, #T_9b2e3_row3_col6, #T_9b2e3_row3_col7, #T_9b2e3_row3_col8, #T_9b2e3_row3_col9, #T_9b2e3_row3_col10, #T_9b2e3_row4_col1, #T_9b2e3_row4_col2, #T_9b2e3_row4_col3, #T_9b2e3_row4_col4, #T_9b2e3_row4_col5, #T_9b2e3_row4_col6, #T_9b2e3_row4_col7, #T_9b2e3_row4_col8, #T_9b2e3_row4_col9, #T_9b2e3_row4_col10, #T_9b2e3_row5_col1, #T_9b2e3_row5_col2, #T_9b2e3_row5_col3, #T_9b2e3_row5_col4, #T_9b2e3_row5_col5, #T_9b2e3_row5_col6, #T_9b2e3_row5_col7, #T_9b2e3_row5_col8, #T_9b2e3_row5_col9, #T_9b2e3_row5_col10, #T_9b2e3_row6_col1, #T_9b2e3_row6_col2, #T_9b2e3_row6_col3, #T_9b2e3_row6_col4, #T_9b2e3_row6_col5, #T_9b2e3_row6_col6, #T_9b2e3_row6_col7, #T_9b2e3_row6_col8, #T_9b2e3_row6_col9, #T_9b2e3_row6_col10, #T_9b2e3_row7_col1, #T_9b2e3_row7_col2, #T_9b2e3_row7_col3, #T_9b2e3_row7_col4, #T_9b2e3_row7_col5, #T_9b2e3_row7_col6, #T_9b2e3_row7_col7, #T_9b2e3_row7_col8, #T_9b2e3_row7_col9, #T_9b2e3_row7_col10, #T_9b2e3_row8_col1, #T_9b2e3_row8_col2, #T_9b2e3_row8_col3, #T_9b2e3_row8_col4, #T_9b2e3_row8_col5, #T_9b2e3_row8_col6, #T_9b2e3_row8_col7, #T_9b2e3_row8_col8, #T_9b2e3_row8_col9, #T_9b2e3_row8_col10, #T_9b2e3_row9_col1, #T_9b2e3_row9_col2, #T_9b2e3_row9_col3, #T_9b2e3_row9_col4, #T_9b2e3_row9_col5, #T_9b2e3_row9_col6, #T_9b2e3_row9_col7, #T_9b2e3_row9_col8, #T_9b2e3_row9_col9, #T_9b2e3_row9_col10, #T_9b2e3_row10_col1, #T_9b2e3_row10_col2, #T_9b2e3_row10_col3, #T_9b2e3_row10_col4, #T_9b2e3_row10_col5, #T_9b2e3_row10_col6, #T_9b2e3_row10_col7, #T_9b2e3_row10_col8, #T_9b2e3_row10_col9, #T_9b2e3_row10_col10, #T_9b2e3_row11_col1, #T_9b2e3_row11_col2, #T_9b2e3_row11_col3, #T_9b2e3_row11_col4, #T_9b2e3_row11_col5, #T_9b2e3_row11_col6, #T_9b2e3_row11_col7, #T_9b2e3_row11_col8, #T_9b2e3_row11_col9, #T_9b2e3_row11_col10, #T_9b2e3_row12_col1, #T_9b2e3_row12_col2, #T_9b2e3_row12_col3, #T_9b2e3_row12_col4, #T_9b2e3_row12_col5, #T_9b2e3_row12_col6, #T_9b2e3_row12_col7, #T_9b2e3_row12_col8, #T_9b2e3_row12_col9, #T_9b2e3_row12_col10, #T_9b2e3_row13_col1, #T_9b2e3_row13_col2, #T_9b2e3_row13_col3, #T_9b2e3_row13_col4, #T_9b2e3_row13_col5, #T_9b2e3_row13_col6, #T_9b2e3_row13_col7, #T_9b2e3_row13_col8, #T_9b2e3_row13_col9, #T_9b2e3_row13_col10, #T_9b2e3_row14_col1, #T_9b2e3_row14_col2, #T_9b2e3_row14_col3, #T_9b2e3_row14_col4, #T_9b2e3_row14_col5, #T_9b2e3_row14_col6, #T_9b2e3_row14_col7, #T_9b2e3_row14_col8, #T_9b2e3_row14_col9, #T_9b2e3_row14_col10, #T_9b2e3_row15_col1, #T_9b2e3_row15_col2, #T_9b2e3_row15_col3, #T_9b2e3_row15_col4, #T_9b2e3_row15_col5, #T_9b2e3_row15_col6, #T_9b2e3_row15_col7, #T_9b2e3_row15_col8, #T_9b2e3_row15_col9, #T_9b2e3_row15_col10, #T_9b2e3_row16_col1, #T_9b2e3_row16_col2, #T_9b2e3_row16_col3, #T_9b2e3_row16_col4, #T_9b2e3_row16_col5, #T_9b2e3_row16_col6, #T_9b2e3_row16_col7, #T_9b2e3_row16_col8, #T_9b2e3_row16_col9, #T_9b2e3_row16_col10, #T_9b2e3_row17_col1, #T_9b2e3_row17_col2, #T_9b2e3_row17_col3, #T_9b2e3_row17_col4, #T_9b2e3_row17_col5, #T_9b2e3_row17_col6, #T_9b2e3_row17_col7, #T_9b2e3_row17_col8, #T_9b2e3_row17_col9, #T_9b2e3_row17_col10, #T_9b2e3_row18_col1, #T_9b2e3_row18_col2, #T_9b2e3_row18_col3, #T_9b2e3_row18_col4, #T_9b2e3_row18_col5, #T_9b2e3_row18_col6, #T_9b2e3_row18_col7, #T_9b2e3_row18_col8, #T_9b2e3_row18_col9, #T_9b2e3_row18_col10, #T_9b2e3_row19_col1, #T_9b2e3_row19_col2, #T_9b2e3_row19_col3, #T_9b2e3_row19_col4, #T_9b2e ...
#   text-align: right;
# }
# </style>
# <table id="T_9b2e3">
#   <thead>
#     <tr>
#       <th id="T_9b2e3_level0_col0" class="col_heading level0 col0" >MedDRA SOC</th>
#       <th id="T_9b2e3_level0_col1" class="col_heading level0 col1" >min.distance</th>
#       <th id="T_9b2e3_level0_col2" class="col_heading level0 col2" >TP</th>
#       <th id="T_9b2e3_level0_col3" class="col_heading level0 col3" >FP</th>
#       <th id="T_9b2e3_level0_col4" class="col_heading level0 col4" >FN</th>
#       <th id="T_9b2e3_level0_col5" class="col_heading level0 col5" >TN</th>
#       <th id="T_9b2e3_level0_col6" class="col_heading level0 col6" >Sensitivity</th>
#       <th id="T_9b2e3_level0_col7" class="col_heading level0 col7" >Specificity</th>
#       <th id="T_9b2e3_level0_col8" class="col_heading level0 col8" >LR+</th>
#       <th id="T_9b2e3_level0_col9" class="col_heading level0 col9" >LR-</th>
#       <th id="T_9b2e3_level0_col10" class="col_heading level0 col10" >chi-square</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b2e3_row0_col0" class="data row0 col0" >Nervous system disorders</td>
#       <td id="T_9b2e3_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_9b2e3_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_9b2e3_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_9b2e3_row0_col4" class="data row0 col4" >7</td>
#       <td id="T_9b2e3_row0_col5" class="data row0 col5" >293</td>
#       <td id="T_9b2e3_row0_col6" class="data row0 col6" >0.125000</td>
#       <td id="T_9b2e3_row0_col7" class="data row0 col7" >0.989865</td>
#       <td id="T_9b2e3_row0_col8" class="data row0 col8" >12.333333</td>
#       <td id="T_9b2e3_row0_col9" class="data row0 col9" >0.883959</td>
#       <td id="T_9b2e3_row0_col10" class="data row0 col10" >7.914955</td>
#     </tr>
#     <tr>
#       <td id="T_9b2e3_row1_col0" class="data row1 col0" >Musculoskeletal and connective tissue disorders</td>
#       <td id="T_9b2e3_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_9b2e3_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_9b2e3_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_9b2e3_row1_col4" class="data row1 col4" >74</td>
#       <td id="T_9b2e3_row1_col5" class="data row1 col5" >212</td>
#       <td id="T_9b2e3_row1_col6" class="data row1 col6" >0.139535</td>
#       <td id="T_9b2e3_row1_col7" class="data row1 col7" >0.972477</td>
#       <td id="T_9b2e3_row1_col8" class="data row1 col8" >5.069767</td>
#       <td id="T_9b2e3_row1_col9" class="data row1 col9" >0.884818</td>
#       <td id="T_9b2e3_row1_col10" class="data row1 col10" >13.890526</td>
#     </tr>
#     <tr>
#       <td id="T_9b2e3_row2_col0" class="data row2 col0" >Pregnancy, puerperium and perinatal conditions</td>
#       <td id="T_9b2e3_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_9b2e3_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_9b2e3_row2_col3" class="data row2 col3" >20</td>
#       <td id="T_9b2e3_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_9b2e3_row2_col5" class="data row2 col5" >280</td>
#       <td id="T_9b2e3_row2_col6" class="data row2 col6" >0.250000</td>
#       <td id="T_9b2e3_row2_col7" clas

# %%
html = df.to_html(index=False, justify='right', border=1)

#write html to file
text_file = open("../data/concordance_" + level.upper() + ".html", "w")
text_file.write(html)
text_file.close()
